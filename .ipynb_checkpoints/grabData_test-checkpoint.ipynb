# %%
import pandas as pd
import requests

# %%
url = 'https://api.covid19api.com/summary'

# %%
r= requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
json = r.json()

# %%
json
# Out:
# {'ID': '96fecf39-98b5-4187-a11d-14d4ba421bc1',
#  'Message': '',
#  'Global': {'NewConfirmed': 243433,
#   'TotalConfirmed': 669252736,
#   'NewDeaths': 2363,
#   'TotalDeaths': 6755116,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-04T18:05:51.686Z'},
#  'Countries': [{'ID': '4f437e04-cb57-442d-9e60-e8c9fe7f4ad7',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 208669,
#    'NewDeaths': 0,
#    'TotalDeaths': 7891,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-04T18:05:51.686Z',
#    'Premium': {}},
#   {'ID': '85b7f7a1-86c8-4b67-8a15-803a5030d226',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 334203,
#    'NewDeaths': 0,
#    'TotalDeaths': 3596,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-02-04T18:05:51.686Z',
#    'Premium': {}},
# ...

# %%
json.keys()
# Out:
# dict_keys(['ID', 'Message', 'Global', 'Countries', 'Date'])

# %%
json['ID']
# Out:
# '96fecf39-98b5-4187-a11d-14d4ba421bc1'

# %% [markdown]
# thats the api key? ^^

# %%
json['Global']
# Out:
# {'NewConfirmed': 243433,
#  'TotalConfirmed': 669252736,
#  'NewDeaths': 2363,
#  'TotalDeaths': 6755116,
#  'NewRecovered': 0,
#  'TotalRecovered': 0,
#  'Date': '2023-02-04T18:05:51.686Z'}

# %% [markdown]
# this is totals out of everything,, i think ^^

# %%
json['Countries']
# Out:
# [{'ID': '4f437e04-cb57-442d-9e60-e8c9fe7f4ad7',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 208669,
#   'NewDeaths': 0,
#   'TotalDeaths': 7891,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-04T18:05:51.686Z',
#   'Premium': {}},
#  {'ID': '85b7f7a1-86c8-4b67-8a15-803a5030d226',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 16,
#   'TotalConfirmed': 334203,
#   'NewDeaths': 0,
#   'TotalDeaths': 3596,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-04T18:05:51.686Z',
#   'Premium': {}},
#  {'ID': 'd3e8be38-c95f-40eb-b51b-ec8bc44d50cf',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 8,
#   'TotalConfirmed': 271394,
#   'NewDeaths': 0,
#   'TotalDeaths': 6881,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-02-04T18:05:51.686Z',
#   'Premium': {}},
# ...

# %%
json['Date']
# Out:
# '2023-02-04T18:05:51.686Z'

# %% [markdown]
# check types with type(json['key'])

# %%
type(json['Global'])
# Out:
# dict

# %%
type(json['Date'])
# Out:
# str

# %%
type(json['Countries'])
# Out:
# list

# %% [markdown]
# find what the list is storing, i.e list of dicts, strings, etc by testing a single index

# %%
type(json['Countries'][0])
# Out:
# dict

# %% [markdown]
# list is of dicts so it can be dataframed yahoo. now toss into df real ez

# %%
df = pd.DataFrame(json['Countries'])

# %%
df
# Out:
#                                        ID                          Country  \
# 0    4f437e04-cb57-442d-9e60-e8c9fe7f4ad7                      Afghanistan
# 1    85b7f7a1-86c8-4b67-8a15-803a5030d226                          Albania
# 2    d3e8be38-c95f-40eb-b51b-ec8bc44d50cf                          Algeria
# 3    9bd23afc-2847-4ba9-9375-f6ff3a8cb4da                          Andorra
# 4    15992542-f8d8-4e9c-838b-205c4bd2e907                           Angola
# ..                                    ...                              ...
# 192  ce0596f6-3965-4e37-b28c-cb92c17a2664  Venezuela (Bolivarian Republic)
# 193  374ac827-429b-4c33-9092-223f9a3499b3                         Viet Nam
# 194  53e78e2c-49d0-4820-8adc-ea3a0b45146d                            Yemen
# 195  e2c5f3f6-677d-4beb-ba3c-bccea9ff3262                           Zambia
# 196  4e0082e9-3afc-4dc5-a13e-eba75536c571                         Zimbabwe
#
# ...
